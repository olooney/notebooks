# %%
from zalgo_text import zalgo

print(zalgo.zalgo().zalgofy("Video Art"))
# Out:
# V̹̹ͣi̡͖͢d̬̉̕ȅ̡̬o͈̜͍ Á̦̘ṟͦ͢t̵̷̼

# %%
z = zalgo.zalgo()

# %%
z.dm
# Out:
# [' ̕',
#  ' ̛',
#  ' ̀',
#  ' ́',
#  ' ͘',
#  ' ̡',
#  ' ̢',
#  ' ̧',
#  ' ̨',
#  ' ̴',
#  ' ̵',
#  ' ̶',
#  ' ͜',
#  ' ͝',
#  ' ͞',
#  ' ͟',
#  ' ͠',
#  ' ͢',
#  ' ̸',
#  ' ̷',
#  ' ͡']

# %%
z.dd
# Out:
# ['̖',
#  ' ̗',
#  ' ̘',
#  ' ̙',
#  ' ̜',
#  ' ̝',
#  ' ̞',
#  ' ̟',
#  ' ̠',
#  ' ̤',
#  ' ̥',
#  ' ̦',
#  ' ̩',
#  ' ̪',
#  ' ̫',
#  ' ̬',
#  ' ̭',
#  ' ̮',
#  ' ̯',
#  ' ̰',
#  ' ̱',
#  ' ̲',
#  ' ̳',
#  ' ̹',
#  ' ̺',
#  ' ̻',
#  ' ̼',
#  ' ͅ',
#  ' ͇',
#  ' ͈',
#  ' ͉',
#  ' ͍',
#  ' ͎',
#  ' ͓',
#  ' ͔',
#  ' ͕',
#  ' ͖',
#  ' ͙',
#  ' ͚',
#  ' ']

# %%
z.du
# Out:
# [' ̍',
#  ' ̎',
#  ' ̄',
#  ' ̅',
#  ' ̿',
#  ' ̑',
#  ' ̆',
#  ' ̐',
#  ' ͒',
#  ' ͗',
#  ' ͑',
#  ' ̇',
#  ' ̈',
#  ' ̊',
#  ' ͂',
#  ' ̓',
#  ' ̈́',
#  ' ͊',
#  ' ͋',
#  ' ͌',
#  ' ̃',
#  ' ̂',
#  ' ̌',
#  ' ͐',
#  ' ́',
#  ' ̋',
#  ' ̏',
#  ' ̽',
#  ' ̉',
#  ' ͣ',
#  ' ͤ',
#  ' ͥ',
#  ' ͦ',
#  ' ͧ',
#  ' ͨ',
#  ' ͩ',
#  ' ͪ',
#  ' ͫ',
#  ' ͬ',
#  ' ͭ',
#  ' ͮ',
#  ' ͯ',
#  ' ̾',
#  ' ͛',
#  ' ͆',
#  ' ̚']

# %%
z.maxAccentsPerLetter
# Out:
# 3

# %%
zalgo.__file__
# Out:
# 'C:\\Users\\oloon\\miniconda3\\envs\\py312\\Lib\\site-packages\\zalgo_text\\zalgo.py'

# %%
with open(zalgo.__file__, encoding='utf-8') as f:
    c = f.read()

# %%
print(c)
# Out:
# import random
#
# class zalgo():
#
# 	def __init__(self):
# 		self.numAccentsUp = (1, 3)
# 		self.numAccentsDown = (1,3)
# 		self.numAccentsMiddle = (1,2)
# 		self.maxAccentsPerLetter = 3
# 		#downward going diacritics
# 		self.dd = ['̖',' ̗',' ̘',' ̙',' ̜',' ̝',' ̞',' ̟',' ̠',' ̤',' ̥',' ̦',' ̩',' ̪',' ̫',' ̬',' ̭',' ̮',' ̯',' ̰',' ̱',' ̲',' ̳',' ̹',' ̺',' ̻',' ̼',' ͅ',' ͇',' ͈',' ͉',' ͍',' ͎',' ͓',' ͔',' ͕',' ͖',' ͙',' ͚',' ',]
# 		#upward diacritics
# 		self.du = [' ̍',' ̎',' ̄',' ̅',' ̿',' ̑',' ̆',' ̐',' ͒',' ͗',' ͑',' ̇',' ̈',' ̊',' ͂',' ̓',' ̈́',' ͊',' ͋',' ͌',' ̃',' ̂',' ̌',' ͐',' ́',' ̋',' ̏',' ̽',' ̉',' ͣ',' ͤ',' ͥ',' ͦ',' ͧ',' ͨ',' ͩ',' ͪ',' ͫ',' ͬ',' ͭ',' ͮ',' ͯ',' ̾',' ͛',' ͆',' ̚',]
# 		#build the alterations - zalgo and [text](/a) for shaking angery text
# 		self.dm = [' ̕',' ̛',' ̀',' ́',' ͘',' ̡',' ̢',' ̧',' ̨',' ̴',' ̵',' ̶',' ͜',' ͝',' ͞',' ͟',' ͠',' ͢',' ̸',' ̷',' ͡',]
#
# 	def zalgofy(self, text):
# 		'''
# 		Zalgofy a string
# 		'''
# 		#get the letters list
# ...
